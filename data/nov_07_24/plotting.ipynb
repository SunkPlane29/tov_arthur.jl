# %%
import numpy as np 
import matplotlib.pyplot as plt 
import scienceplots 
import pandas as pd

plt.style.use('science')

# %%
df = pd.read_csv("/home/arthuro/tov.jl/data/nov_07_24/EOSTRS1.5.dat", delimiter='\s+', header=None)
df.iloc[::-1].reset_index(drop=True).to_csv("data1.csv",header=None,index=None)

# %%
df = pd.read_csv("/home/arthuro/tov.jl/data/nov_07_24/EOSTRS1.4.dat", delimiter='\s+', header=None)
df.iloc[::-1].reset_index(drop=True).to_csv("data2.csv",header=None,index=None)

# %%
df = pd.read_csv("/home/arthuro/tov.jl/data/nov_07_24/EOSTRS1.3.dat", delimiter='\s+', header=None)
df.iloc[::-1].reset_index(drop=True).to_csv("data3.csv",header=None,index=None)

# %%
x = np.linspace(0.0,2000.0,100)
y = (x-4*57.5)/3
df = pd.DataFrame({0:x,1:y})
df.reset_index(drop=True).to_csv("data_MIT.csv",header=None,index=None)

# %%
df = pd.read_csv("/home/arthuro/tov.jl/data/nov_07_24/EOSMSS1.3.dat", delimiter='\s+', header=None)
df.iloc[::-1].reset_index(drop=True).to_csv("data_mss13.csv",header=None,index=None)

# %%
# agora eu vou plotar as curvas massa raio 
plt.figure(figsize=(6,4))

mit_color= "#ef476f"

eta_13 = "#ffd166"
eta_14 = "#06d6a0"
eta_15 = "#118ab2"

# MIT BAG MODEL 
data1 = pd.read_csv("MR_diag_MIT.csv")
plt.plot(data1.M,data1.R,label="MIT $B^{1/4}=145$ MeV",color=mit_color)


# TRS
data1 = pd.read_csv("MR_diag_TRS_13.csv")
plt.plot(data1.M,data1.R,label="TRS $\eta=1.3$",ls='--',color=eta_13)

data1 = pd.read_csv("MR_diag_TRS_14.csv")
plt.plot(data1.M,data1.R,label="TRS $\eta=1.4$",ls='--',color=eta_14)

data1 = pd.read_csv("MR_diag_TRS_15.csv")
plt.plot(data1.M,data1.R,label="TRS $\eta=1.5$",ls='--',color=eta_15)


# MSS
data1 = pd.read_csv("MR_diag_MSS13.csv")
plt.plot(data1.M,data1.R,label="MSS $\eta=1.3$",ls='-',color=eta_13)

data1 = pd.read_csv("MR_diag_MSS14.csv")
plt.plot(data1.M,data1.R,label="MSS $\eta=1.4$",ls='-',color=eta_14)

data1 = pd.read_csv("MR_diag_MSS15.csv")
plt.plot(data1.M,data1.R,label="MSS $\eta=1.5$",ls='-',color=eta_15)

plt.xlabel("$R$[km]",fontsize=14)
plt.ylabel("$M$[$M_{\odot}$]",fontsize=14)


color = "#ee9b00"
plt.fill(j0030_1[0],j0030_1[1],alpha=0.5,ls='-',edgecolor='black',lw=2,color=color)
plt.fill(j0030_2[0],j0030_2[1],alpha=0.5,ls='-',edgecolor='black',lw=2,color=color)

color = "#ae2012"
plt.fill(j0740_1[0],j0740_1[1],alpha=0.5,ls='-',edgecolor='black',lw=2,color=color)
plt.fill(j0740_2[0],j0740_2[1],alpha=0.5,ls='-',edgecolor='black',lw=2,color=color)

# regioes
color = "#ffbe0b"
plt.fill(gw170817_1[0],gw170817_1[1],alpha=0.5,ls='-',edgecolor='black',lw=2,color=color)
plt.fill(gw170817_2[0],gw170817_2[1],alpha=0.5,ls='-',edgecolor='black',lw=2,color=color)

color = "#0a9396"
plt.fill(spec_gw170817_1[0],spec_gw170817_1[1],alpha=0.5,ls='-',edgecolor='black',lw=2,color=color)
plt.fill(spec_gw170817_2[0],spec_gw170817_2[1],alpha=0.5,ls='-',edgecolor='black',lw=2,color=color)

plt.ylim(0,5)
plt.xlim(5,30)

plt.grid(alpha=0.2)
plt.legend(fontsize=10,loc=2)

plt.savefig("mr_diagrams_02_07nov24.png",dpi=300)
plt.show()

# %%
gw170817_1 = pd.read_csv("/home/arthuro/tov.jl/data/GW170817_EOS_insensitive_90confidence_R1[km]_m1[Msun].dat",delimiter='\s+', header=None)
gw170817_2 = pd.read_csv("/home/arthuro/tov.jl/data/GW170817_EOS_insensitive_90confidence_R2[km]_m2[Msun].dat",delimiter='\s+', header=None)

spec_gw170817_1 = pd.read_csv("/home/arthuro/tov.jl/data/GW170817_spectralEOS_wMaxm_90confidence_R1[km]_m1[Msun].dat",delimiter='\s+', header=None)
spec_gw170817_2 = pd.read_csv("/home/arthuro/tov.jl/data/GW170817_spectralEOS_wMaxm_90confidence_R2[km]_m2[Msun].dat",delimiter='\s+', header=None)

j0030_1 = pd.read_csv("/home/arthuro/tov.jl/data/J0030_2spot_90confidence_R[km]_m[Msun].dat",delimiter='\s+', header=None)
j0030_2 = pd.read_csv("/home/arthuro/tov.jl/data/J0030_Amstd_ST_PST_90_R[km]_m[Msun].dat",delimiter='\s+', header=None)

j0740_1 = pd.read_csv("/home/arthuro/tov.jl/data/J0740_Amstd_NICERxXMM___XPSI_STU_NSX_FIH__90_R[km]_m[Msun].dat",delimiter='\s+', header=None)
j0740_2 = pd.read_csv("/home/arthuro/tov.jl/data/J0740_IllinoisMaryland__NICER_XMM_relative__90_R[km]_m[Msun].dat",delimiter='\s+', header=None)

# %%
plt.fill(data[0],data[1],alpha=1,ls='-',edgecolor='black',lw=3,)

# %%
# agora eu vou plotar as curvas massa raio 
plt.figure(figsize=(6,4))

mit_color= "#ef476f"

eta_13 = "#ffd166"
eta_14 = "#06d6a0"
eta_15 = "#118ab2"

# MIT BAG MODEL 
data1 = pd.read_csv("MR_diag_MIT.csv")
plt.plot(data1.M,data1.R,label="MIT $B^{1/4}=145$ MeV",color=mit_color)


# TRS
data1 = pd.read_csv("MR_diag_TRS_13.csv")
plt.plot(data1.M,data1.R,label="TRS $\eta=1.3$",ls='--',color=eta_13)

data1 = pd.read_csv("MR_diag_TRS_14.csv")
plt.plot(data1.M,data1.R,label="TRS $\eta=1.4$",ls='--',color=eta_14)


# MSS
data1 = pd.read_csv("MR_diag_MSS13.csv")
plt.plot(data1.M,data1.R,label="MSS $\eta=1.3$",ls='-',color=eta_13)

data1 = pd.read_csv("MR_diag_MSS14.csv")
plt.plot(data1.M,data1.R,label="MSS $\eta=1.4$",ls='-',color=eta_14)


plt.xlabel("$R$[km]",fontsize=14)
plt.ylabel("$M$[$M_{\odot}$]",fontsize=14)


color = "#ee9b00"
plt.fill(j0030_1[0],j0030_1[1],alpha=0.5,ls='-',edgecolor='black',lw=2,color=color)
plt.fill(j0030_2[0],j0030_2[1],alpha=0.5,ls='-',edgecolor='black',lw=2,color=color)

color = "#ae2012"
plt.fill(j0740_1[0],j0740_1[1],alpha=0.5,ls='-',edgecolor='black',lw=2,color=color)
plt.fill(j0740_2[0],j0740_2[1],alpha=0.5,ls='-',edgecolor='black',lw=2,color=color)

# regioes
color = "#ffbe0b"
plt.fill(gw170817_1[0],gw170817_1[1],alpha=0.5,ls='-',edgecolor='black',lw=2,color=color)
plt.fill(gw170817_2[0],gw170817_2[1],alpha=0.5,ls='-',edgecolor='black',lw=2,color=color)

color = "#0a9396"
plt.fill(spec_gw170817_1[0],spec_gw170817_1[1],alpha=0.5,ls='-',edgecolor='black',lw=2,color=color)
plt.fill(spec_gw170817_2[0],spec_gw170817_2[1],alpha=0.5,ls='-',edgecolor='black',lw=2,color=color)

plt.ylim(0,3.4)
plt.xlim(5,18)

plt.grid(alpha=0.2)
plt.legend(fontsize=10,loc=2)

plt.savefig("mr_diagrams_02_07nov24.png",dpi=300)
plt.show()
